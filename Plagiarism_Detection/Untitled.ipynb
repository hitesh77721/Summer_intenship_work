# %%
from plagiarism import compare_uploaded_document

with open("assignment.txt", "r", encoding="utf-8") as f:
    text = f.read()

df = compare_uploaded_document(text)

print(df)
# Out:
#    Document  Similarity (%)
# 0  doc1.txt           77.67
# 1  doc4.txt           77.52
# 2  doc2.txt           75.39
# 3  doc3.txt            9.69
