# %%
from plagiarism import *

documents = read_documents("data")

normalized = preprocess_documents(documents)

similarity_matrix = calculate_similarity(normalized)

filenames = list(normalized.keys())

results = get_plagiarism_cases(similarity_matrix, filenames)

print(results)
# Out:
# [{'file1': 'doc1.txt', 'file2': 'doc2.txt', 'similarity': np.float64(86.61)}, {'file1': 'doc1.txt', 'file2': 'doc4.txt', 'similarity': np.float64(86.85)}, {'file1': 'doc2.txt', 'file2': 'doc4.txt', 'similarity': np.float64(87.16)}]
